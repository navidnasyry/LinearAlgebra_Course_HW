# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d

from IPython.display import clear_output

import pandas as pd
import numpy as np
classes = {0:'T-shirt/top',
           1:'Trouser', 
           2: 'Pullover', 
           3: 'Dress', 
           4: 'Coat',
           5: 'Sandal',
           6: 'Shirt',
           7: 'Sneaker',
           8: 'Bag', 
           9: 'Ankle Boot'}

# %%
selected_labels = [0, 1, 5, 8, 9]

data = pd.read_csv('fashion_MNIST/fashion-mnist_train.csv')
data = data.loc[data['label'].isin(selected_labels)].reset_index(drop=True)

labels = data.pop('label')
index = 0
data = data.values
images = np.reshape(data, (-1, 28, 28))

# %%
import matplotlib.pyplot as plt
plt.imshow(images[index].squeeze(), cmap = 'gray')
plt.title(classes[labels[index]])
plt.axis('off')
plt.show()
index += 1

# %% [markdown]
# # PCA step by step
# Here is the short summary of the required steps:
# * **Scale the data** — we don’t want some feature to be voted as “more important” due to scale differences. 10m = 10000mm, but the algorithm isn’t aware of meters and millimeters
# * **Calculate covariance matrix** — square matrix giving the covariances between each pair of elements of a random vector
# * **Eigen Decomposition**

# %% [markdown]
# # Scale the Data:
# Standardize features. to do so, use this formula: $$z = \frac{(x - \mu)}{\sigma}$$
# where $\mu$ is mean and $\sigma$ is standard deviation.

# %%
# Code Here
test = np.array([[[1,2,3,4], [2,2,2,4], [10,20,30,4], [20,20,20,4]], [[10,20,30,40], [20,20,20,40], [100,200,300,40], [200,200,200,40]]])
# Mean of all pixels at the same location :
# for example : main_[0,0] = mean(image[0,0,0] , image[1,0,0], ...)

mean_ = np.mean(images, axis= 0)

# Std of all pixels at the same location :
# for example : std_[0,0] = std(image[0,0,0] , image[1,0,0], ...)
std_ = np.std(images, axis= 0)

# and finally : 
X_scaled = (images - mean_) / std_ 



import matplotlib.pyplot as plt
plt.imshow(X_scaled[index].squeeze(), cmap = 'gray')
plt.title(classes[labels[index]])
plt.axis('off')
plt.show()
index += 1
X_scaled[index]
X_scaled.shape
# Out:
# (30000, 28, 28)

# %% [markdown]
# # Calculate Covariance Matrix:
# Let’s take a step back here and understand the difference between variance and covariance. Variance reports variation of a single random variable — let’s say the weight of a person, and covariance reports how much two random variables vary — like weight and height of a person.
# On the diagonal of the covariance matrix we have variances, and other elements are the covariances.
#
# For further information about covariance visit [wikipedia](https://en.wikipedia.org/wiki/Covariance).

# %%
images.shape[0]
# Out:
# 30000

# %%
# CODE Here
# using built-in functions like np.cov is NOT allowed
images.shape[1]
# number of all images
num = images.shape[0]

images_1d = images.reshape(images.shape[0], images.shape[1] * images.shape[2])
cov_matrix = (images_1d.T @ images_1d) / num


# # dimention of main cov_matrix
# X = cov_matrix.shape[0]
# Y = cov_matrix.shape[1]
# print(X, Y)

    ## bad approch :(
# dimentin of each images
# img_x = images.shape[1]
# img_y = images.shape[2]
# cov_matrix = np.zeros((images.shape[1] ** 2 , images.shape[2] **2))
# for i in range(X):
#     for j in range(Y):
#         cov_sum = 0
#         for img in images:
#             cov_sum += ((img[int(i/img_x), int(i%img_x)] - mean_[int(i/img_x), int(i%img_x)]) *
#          ""               (img[int(j/img_x), int(j%img_x)] - mean_[int(i/img_x), int(i%img_x)]))
        
#         cov_matrix[i, j] = cov_sum / num


print(cov_matrix)
assert cov_matrix.shape == (784,784) , "covariance matrix shape should be 784 * 784"

cov_matrix[0:5, 0:5]
# Out:
# [[2.06666667e-03 1.66666667e-03 1.73333333e-03 ... 6.56666667e-03
#   3.30000000e-03 1.66666667e-03]
#  [1.66666667e-03 1.25100000e-01 3.57900000e-01 ... 6.03333333e-02
#   5.09000000e-02 5.86666667e-03]
#  [1.73333333e-03 3.57900000e-01 2.21646667e+00 ... 1.05366667e-01
#   5.25666667e-02 5.13333333e-03]
#  ...
#  [6.56666667e-03 6.03333333e-02 1.05366667e-01 ... 3.49250100e+02
#   1.60929700e+02 1.36601333e+01]
#  [3.30000000e-03 5.09000000e-02 5.25666667e-02 ... 1.60929700e+02
#   1.40528833e+02 1.44731667e+01]
#  [1.66666667e-03 5.86666667e-03 5.13333333e-03 ... 1.36601333e+01
#   1.44731667e+01 7.09656667e+00]]
# array([[2.06666667e-03, 1.66666667e-03, 1.73333333e-03, 3.30000000e-03,
#         5.20000000e-03],
#        [1.66666667e-03, 1.25100000e-01, 3.57900000e-01, 1.57033333e-01,
#         8.37666667e-02],
#        [1.73333333e-03, 3.57900000e-01, 2.21646667e+00, 1.18916667e+00,
#         2.37100000e-01],
#        [3.30000000e-03, 1.57033333e-01, 1.18916667e+00, 7.35520000e+00,
#         6.49726667e+00],
#        [5.20000000e-03, 8.37666667e-02, 2.37100000e-01, 6.49726667e+00,
#         1.86558000e+01]])

# %% [markdown]
# As you can see, the diagonal elements are identical, and the matrix is symmetrical. Up next, eigendecomposition.

# %% [markdown]
# # Eigendecomposition
# `Eigendecomposition is a process that decomposes a square matrix into eigenvectors and eigenvalues.` <font color='red'>Eigenvectors are simple unit vectors</font>, and <font color='green'>eigenvalues are coefficients which give the magnitude to the eigenvectors. </font>
#
# We know so far that our `covariance matrix is symmetrical.` As it turns out, `eigenvectors of symmetric matrices are orthogonal.` For PCA this means that we have the first principal component which explains most of the variance. Orthogonal to that is the second principal component, which explains most of the remaining variance. This is repeated for N number of principal components, where N equals to number of original features.
#
# And this turns out to be neat for us — principal components are sorted by percentage of variance explained, as we can decide how many should we keep. For example, if we have 100 features originally, but the first 3 principal components explain 95% of the variance, then it makes sense to keep only these 3 for visualizations and model training.

# %%
# Code Here
# Implementing the functions to return eigen vectors and values are optional and have extra score.

def cal_eig_values():
    pass
def cal_eig_vectors():
    pass

eig_values = np.linalg.eig(cov_matrix)[0]
eig_vectors = np.linalg.eig(cov_matrix)[1]

print(eig_values)
print(eig_vectors)

##


print(f'First 10 eigenvalues: {eig_values[:10]}')
print(f'\n\nLast 10 eigenvalues: {eig_values[-10:]}')
# Out:
# [6.15052685e+06 1.16679009e+06 3.45654510e+05 3.08110728e+05
#  2.34473622e+05 1.36591861e+05 9.26334713e+04 6.27979138e+04
#  5.37055556e+04 4.91995057e+04 4.16695788e+04 3.73550544e+04
#  3.52136763e+04 3.18801959e+04 2.97663756e+04 2.74891158e+04
#  2.58291030e+04 2.31603222e+04 2.12560679e+04 2.03574093e+04
#  134.41317171 132.01611167 139.19553848 141.16386583 133.6807977 ]

# %%
plt.figure(figsize=(5,3))
plt.stem(eig_values[:200])
plt.xlabel('Eigen value index')
plt.ylabel('Eigen value')
plt.show()

# %%
for i in range(200):
    exp_var = np.sum(eig_values[:i+1])*100 / np.sum(eig_values)
    print(f'Eigenvectors upto {i+1} expresses {exp_var} % variance')
# Out:
# Eigenvectors upto 1 expresses 62.19882531566398 % variance
# Eigenvectors upto 2 expresses 73.99829793223385 % variance
# Eigenvectors upto 3 expresses 77.493820343945 % variance
# Eigenvectors upto 4 expresses 80.60967136343261 % variance
# Eigenvectors upto 5 expresses 82.98084772271902 % variance
# Eigenvectors upto 6 expresses 84.36216894743549 % variance
# Eigenvectors upto 7 expresses 85.29894936283152 % variance
# Eigenvectors upto 8 expresses 85.93400983178346 % variance
# Eigenvectors upto 9 expresses 86.47712143017795 % variance
# Eigenvectors upto 10 expresses 86.97466441016668 % variance
# Eigenvectors upto 11 expresses 87.39605901822395 % variance
# Eigenvectors upto 12 expresses 87.77382185959237 % variance
# Eigenvectors upto 13 expresses 88.1299294505376 % variance
# Eigenvectors upto 14 expresses 88.45232634193732 % variance
# Eigenvectors upto 15 expresses 88.7533466677613 % variance
# Eigenvectors upto 16 expresses 89.03133760338183 % variance
# Eigenvectors upto 17 expresses 89.29254122159853 % variance
# Eigenvectors upto 18 expresses 89.52675608986394 % variance
# Eigenvectors upto 19 expresses 89.74171368371306 % variance
# Eigenvectors upto 20 expresses 89.94758335560027 % variance
# Eigenvectors upto 21 expresses 90.14756951543342 % variance
# Eigenvectors upto 22 expresses 90.33181478561279 % variance
# Eigenvectors upto 23 expresses 90.51099338346565 % variance
# Eigenvectors upto 24 expresses 90.67948200092698 % variance
# Eigenvectors upto 25 expresses 90.842689113868 % variance
# Eigenvectors upto 26 expresses 90.99500034174991 % variance
# Eigenvectors upto 27 expresses 91.14101924645163 % variance
# Eigenvectors upto 28 expresses 91.28253856732093 % variance
# Eigenvectors upto 29 expresses 91.4199736368217 % variance
# Eigenvectors upto 30 expresses 91.55447525864598 % variance
# Eigenvectors upto 31 expresses 91.68304267830092 % variance
# Eigenvectors upto 32 expresses 91.80637162293544 % variance
# Eigenvectors upto 33 expresses 91.92455108991675 % variance
# Eigenvectors upto 34 expresses 92.03364351992938 % variance
# Eigenvectors upto 35 expresses 92.14119825719263 % variance
# Eigenvectors upto 36 expresses 92.24535317003557 % variance
# Eigenvectors upto 37 expresses 92.34864374229483 % variance
# Eigenvectors upto 38 expresses 92.4481422267323 % variance
# Eigenvectors upto 39 expresses 92.54507404024226 % variance
# Eigenvectors upto 40 expresses 92.63944382967647 % variance
# Eigenvectors upto 41 expresses 92.73018830790203 % variance
# Eigenvectors upto 42 expresses 92.81797118301324 % variance
# Eigenvectors upto 43 expresses 92.90281663832305 % variance
# Eigenvectors upto 44 expresses 92.98706824585453 % variance
# Eigenvectors upto 45 expresses 93.06797938115788 % variance
# Eigenvectors upto 46 expresses 93.14833992629468 % variance
# Eigenvectors upto 47 expresses 93.22654265363234 % variance
# Eigenvectors upto 48 expresses 93.30062515628813 % variance
# Eigenvectors upto 49 expresses 93.37423090739037 % variance
# Eigenvectors upto 50 expresses 93.4462413767509 % variance
# Eigenvectors upto 51 expresses 93.51665578532766 % variance
# Eigenvectors upto 52 expresses 93.58432367267282 % variance
# Eigenvectors upto 53 expresses 93.65166437016961 % variance
# Eigenvectors upto 54 expresses 93.71805019606632 % variance
# Eigenvectors upto 55 expresses 93.78231459372972 % variance
# Eigenvectors upto 56 expresses 93.8445102307816 % variance
# Eigenvectors upto 57 expresses 93.9065185203735 % variance
# Eigenvectors upto 58 expresses 93.9671363565017 % variance
# Eigenvectors upto 59 expresses 94.02730584123489 % variance
# Eigenvectors upto 60 expresses 94.08615357900665 % variance
# Eigenvectors upto 61 expresses 94.14308725473384 % variance
# Eigenvectors upto 62 expresses 94.1989830900447 % variance
# Eigenvectors upto 63 expresses 94.25332443828667 % variance
# Eigenvectors upto 64 expresses 94.30619777114892 % variance
# Eigenvectors upto 65 expresses 94.35846887505997 % variance
# Eigenvectors upto 66 expresses 94.41030372342567 % variance
# Eigenvectors upto 67 expresses 94.46114702282034 % variance
# Eigenvectors upto 68 expresses 94.51161680484667 % variance
# Eigenvectors upto 69 expresses 94.56078970090174 % variance
# Eigenvectors upto 70 expresses 94.60924056633803 % variance
# Eigenvectors upto 71 expresses 94.65693373157546 % variance
# Eigenvectors upto 72 expresses 94.70360718066007 % variance
# Eigenvectors upto 73 expresses 94.75002583072005 % variance
# Eigenvectors upto 74 expresses 94.79597165997235 % variance
# Eigenvectors upto 75 expresses 94.84118264713986 % variance
# Eigenvectors upto 76 expresses 94.88544770650242 % variance
# Eigenvectors upto 77 expresses 94.92865610836884 % variance
# Eigenvectors upto 78 expresses 94.97146622242352 % variance
# Eigenvectors upto 79 expresses 95.01327484586261 % variance
# Eigenvectors upto 80 expresses 95.05410389696748 % variance
# Eigenvectors upto 81 expresses 95.09468647747983 % variance
# Eigenvectors upto 82 expresses 95.13478534550535 % variance
# Eigenvectors upto 83 expresses 95.1739477584052 % variance
# Eigenvectors upto 84 expresses 95.21276524106084 % variance
# Eigenvectors upto 85 expresses 95.25126142245195 % variance
# Eigenvectors upto 86 expresses 95.2889223449922 % variance
# Eigenvectors upto 87 expresses 95.32611814681167 % variance
# Eigenvectors upto 88 expresses 95.36276073743879 % variance
# Eigenvectors upto 89 expresses 95.39911496132315 % variance
# Eigenvectors upto 90 expresses 95.4350537895227 % variance
# Eigenvectors upto 91 expresses 95.47078616220375 % variance
# Eigenvectors upto 92 expresses 95.50605592991568 % variance
# Eigenvectors upto 93 expresses 95.54098836494282 % variance
# Eigenvectors upto 94 expresses 95.57586988292736 % variance
# Eigenvectors upto 95 expresses 95.60966265960533 % variance
# Eigenvectors upto 96 expresses 95.64286291702307 % variance
# Eigenvectors upto 97 expresses 95.67586674268959 % variance
# Eigenvectors upto 98 expresses 95.70849183990676 % variance
# Eigenvectors upto 99 expresses 95.74036159667027 % variance
# Eigenvectors upto 100 expresses 95.77184258166866 % variance
# Eigenvectors upto 101 expresses 95.80283399544244 % variance
# Eigenvectors upto 102 expresses 95.83341705894398 % variance
# Eigenvectors upto 103 expresses 95.8634528641778 % variance
# Eigenvectors upto 104 expresses 95.89337484513877 % variance
# Eigenvectors upto 105 expresses 95.92298947070248 % variance
# Eigenvectors upto 106 expresses 95.95256970361604 % variance
# Eigenvectors upto 107 expresses 95.98155339597714 % variance
# Eigenvectors upto 108 expresses 96.01034902998178 % variance
# Eigenvectors upto 109 expresses 96.03900199730316 % variance
# Eigenvectors upto 110 expresses 96.06727613931868 % variance
# Eigenvectors upto 111 expresses 96.09489553545042 % variance
# Eigenvectors upto 112 expresses 96.12279506827186 % variance
# Eigenvectors upto 113 expresses 96.14987994312762 % variance
# Eigenvectors upto 114 expresses 96.1766653393738 % variance
# Eigenvectors upto 115 expresses 96.20323439309296 % variance
# Eigenvectors upto 116 expresses 96.22942814727409 % variance
# Eigenvectors upto 117 expresses 96.25541932576192 % variance
# Eigenvectors upto 118 expresses 96.28128506730276 % variance
# Eigenvectors upto 119 expresses 96.30686075880548 % variance
# Eigenvectors upto 120 expresses 96.33186434194857 % variance
# Eigenvectors upto 121 expresses 96.35711291229615 % variance
# Eigenvectors upto 122 expresses 96.38193722005998 % variance
# Eigenvectors upto 123 expresses 96.40604657333513 % variance
# Eigenvectors upto 124 expresses 96.43061383025956 % variance
# Eigenvectors upto 125 expresses 96.45496334585042 % variance
# Eigenvectors upto 126 expresses 96.4787231531468 % variance
# Eigenvectors upto 127 expresses 96.50210757747928 % variance
# Eigenvectors upto 128 expresses 96.52515012434198 % variance
# Eigenvectors upto 129 expresses 96.54801147684759 % variance
# Eigenvectors upto 130 expresses 96.57065373574902 % variance
# Eigenvectors upto 131 expresses 96.59314334804014 % variance
# Eigenvectors upto 132 expresses 96.61550717021468 % variance
# Eigenvectors upto 133 expresses 96.63738386991889 % variance
# Eigenvectors upto 134 expresses 96.65951094123912 % variance
# Eigenvectors upto 135 expresses 96.68104209539473 % variance
# Eigenvectors upto 136 expresses 96.70243480558798 % variance
# Eigenvectors upto 137 expresses 96.72369673221179 % variance
# Eigenvectors upto 138 expresses 96.74482783491042 % variance
# Eigenvectors upto 139 expresses 96.76585646406394 % variance
# Eigenvectors upto 140 expresses 96.78665478251922 % variance
# Eigenvectors upto 141 expresses 96.80719261470122 % variance
# Eigenvectors upto 142 expresses 96.82763731419567 % variance
# Eigenvectors upto 143 expresses 96.84790468392167 % variance
# Eigenvectors upto 144 expresses 96.8680593128108 % variance
# Eigenvectors upto 145 expresses 96.8881532928013 % variance
# Eigenvectors upto 146 expresses 96.90820176174509 % variance
# Eigenvectors upto 147 expresses 96.92781768466139 % variance
# Eigenvectors upto 148 expresses 96.94732759521408 % variance
# Eigenvectors upto 149 expresses 96.96669831766378 % variance
# Eigenvectors upto 150 expresses 96.98562182515577 % variance
# Eigenvectors upto 151 expresses 97.00468036625249 % variance
# Eigenvectors upto 152 expresses 97.0235182144799 % variance
# Eigenvectors upto 153 expresses 97.04210836979851 % variance
# Eigenvectors upto 154 expresses 97.06061581472342 % variance
# Eigenvectors upto 155 expresses 97.07896887244502 % variance
# Eigenvectors upto 156 expresses 97.09718612819655 % variance
# Eigenvectors upto 157 expresses 97.11521726762608 % variance
# Eigenvectors upto 158 expresses 97.13310814873074 % variance
# Eigenvectors upto 159 expresses 97.15094483279597 % variance
# Eigenvectors upto 160 expresses 97.16834047325342 % variance
# Eigenvectors upto 161 expresses 97.18601131385546 % variance
# Eigenvectors upto 162 expresses 97.20362257389834 % variance
# Eigenvectors upto 163 expresses 97.22078746337345 % variance
# Eigenvectors upto 164 expresses 97.23766741602134 % variance
# Eigenvectors upto 165 expresses 97.254623848231 % variance
# Eigenvectors upto 166 expresses 97.27166178124995 % variance
# Eigenvectors upto 167 expresses 97.28833575585438 % variance
# Eigenvectors upto 168 expresses 97.3048767647045 % variance
# Eigenvectors upto 169 expresses 97.32135100249752 % variance
# Eigenvectors upto 170 expresses 97.33772481591596 % variance
# Eigenvectors upto 171 expresses 97.35376497904659 % variance
# Eigenvectors upto 172 expresses 97.3696357425998 % variance
# Eigenvectors upto 173 expresses 97.38556521496712 % variance
# Eigenvectors upto 174 expresses 97.40128999361336 % variance
# Eigenvectors upto 175 expresses 97.41688952676982 % variance
# Eigenvectors upto 176 expresses 97.43257850245162 % variance
# Eigenvectors upto 177 expresses 97.44794189994403 % variance
# Eigenvectors upto 178 expresses 97.46317905122677 % variance
# Eigenvectors upto 179 expresses 97.47828550283917 % variance
# Eigenvectors upto 180 expresses 97.49332209400285 % variance
# Eigenvectors upto 181 expresses 97.50826130240495 % variance
# Eigenvectors upto 182 expresses 97.5230938627107 % variance
# Eigenvectors upto 183 expresses 97.53787082716094 % variance
# Eigenvectors upto 184 expresses 97.55239759317557 % variance
# Eigenvectors upto 185 expresses 97.56689705606581 % variance
# Eigenvectors upto 186 expresses 97.58125459563666 % variance
# Eigenvectors upto 187 expresses 97.59552009160886 % variance
# Eigenvectors upto 188 expresses 97.60963569486204 % variance
# Eigenvectors upto 189 expresses 97.62380216390154 % variance
# Eigenvectors upto 190 expresses 97.63778348292708 % variance
# Eigenvectors upto 191 expresses 97.6513350726173 % variance
# Eigenvectors upto 192 expresses 97.66497409599728 % variance
# Eigenvectors upto 193 expresses 97.67879669471294 % variance
# Eigenvectors upto 194 expresses 97.69141009128116 % variance
# Eigenvectors upto 195 expresses 97.70520021054118 % variance
# Eigenvectors upto 196 expresses 97.71791556653112 % variance
# Eigenvectors upto 197 expresses 97.7307055345916 % variance
# Eigenvectors upto 198 expresses 97.74448112103448 % variance
# Eigenvectors upto 199 expresses 97.75784491404526 % variance
# Eigenvectors upto 200 expresses 97.77111324365767 % variance

# %% [markdown]
# # Visualizations
# ## Eigenvector Visualization
#
# Project the scaled input into the first and second eigen vector and see the result.

# %%
# Code Here
projected_1 = images_1d @ eig_vectors[:, 0]
projected_2 = images_1d @ eig_vectors[:, 1]


##
res2d = pd.DataFrame(projected_1, columns=['PC1'])
res2d['PC2'] = projected_2
res2d['Y'] = labels
res2d.head()
# Out:
#            PC1          PC2  Y
# 0 -2130.198426  1275.954236  9
# 1 -2883.106542 -1055.551346  0
# 2  -510.031547   253.655776  5
# 3 -2406.066831  -301.701247  8
# 4 -3908.358149 -1597.698142  0

# %% [markdown]
# ## 2D Visualization

# %%
plt.figure(figsize=(10,6))
for label in selected_labels:
    label_name = classes[label]
    coords = res2d[res2d['Y']==label]
    x = coords['PC1'].values
    y = coords['PC2'].values
    plt.scatter(x, y, label=label_name)

plt.legend()
plt.show()

# %% [markdown]
# ## 3D Visualization
#
# Besides the above projections, project the scaled input on the third eigen vector to see the 3D visualization.

# %%
# Code Here
projected_3 = images_1d @ eig_vectors[:, 3]

##
res3d = pd.DataFrame(projected_1, columns=['PC1'])
res3d['PC2'] = projected_2
res3d['PC3'] = projected_3
res3d['Y'] = labels
res3d = res3d.head(500)

# %%
fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(projection='3d')

for label in selected_labels:
    label_name = classes[label]
    coords = res3d[res3d['Y']==label]
    x = coords['PC1'].values
    y = coords['PC2'].values
    z = coords['PC3'].values
    ax.scatter3D(x, y, z, label=label_name)
    
ax.set_xlabel('Principal Component 1')
ax.set_ylabel('Principal Component 2')
ax.set_zlabel('Principal Component 3')
ax.legend()

# %% [markdown]
# # Reconstruction from Principal Component
# ## Reduction/Compression Phase:
# <img src="https://i.stack.imgur.com/CKI4U.png" alt="drawing" style="width:200px;"/>
#
# Above is the general form of vector on vector projection formula, in order to reconstruct our image we need to find the projection of our X_scaled ($a$) on each of the reduced_eigen_space vectors ($v$) (Note that our calculated eigen vectors are unit vectors, therefore, the denominator equals to one).
#
# Determine the number of eigen vectors needed to project image on, such that images can still be recognizable. Note that this number should NOT be accurate and something approximate is enough (don't message TAs about the accuracy :)) ).

# %%
# Code Here

# upper the 7 we can detect output photo :)
number_of_eigen_vectors = 7

##
reduced_eigen_space = eig_vectors[:, :number_of_eigen_vectors]

# %%
# Code Here
X_compressed = images_1d @ reduced_eigen_space

##

assert X_compressed.shape == (X_scaled.shape[0], number_of_eigen_vectors), "shape of X_compresed is wrong"

print(f'Shape of X_scaled: {X_scaled.shape}')
print(f'Shape of reduced_eigen_space: {reduced_eigen_space.shape}')
print(f'Shape of X_compressed: {X_compressed.shape}')
# Out:
# Shape of X_scaled: (30000, 28, 28)
# Shape of reduced_eigen_space: (784, 7)
# Shape of X_compressed: (30000, 7)

# %% [markdown]
# ## Reconstrunction Phase:

# %%
# Code Here
X_reconstructed = X_compressed @ reduced_eigen_space.T               # Reconstructed data
data_reconstructed = X_reconstructed * std_.reshape((1, 784)) + mean_.reshape((1, 784))             # De-standardized data

##

reconstructed_images = np.reshape(data_reconstructed, (-1, 28, 28))

print(f'Shape of X_compressed: {X_compressed.shape}')
print(f'Shape of reduced_eigen_space: {reduced_eigen_space.shape}')
print(f'Shape of X_reconstructed: {X_reconstructed.shape}')
# Out:
# Shape of X_compressed: (30000, 7)
# Shape of reduced_eigen_space: (784, 7)
# Shape of X_reconstructed: (30000, 784)

# %%
rec_index = 0

f = plt.figure()
ax1 = f.add_subplot(1,2,1)
plt.imshow(images[rec_index].squeeze(), cmap = 'gray')
ax1.axis(False)
ax2 = f.add_subplot(1,2,2)
ax2.axis(False)
plt.imshow(reconstructed_images[rec_index].squeeze(), cmap = 'gray')
ax1.title.set_text('Original')
ax2.title.set_text('Reconstructed after Compression')
plt.show(block=True)
rec_index +=1
